# %%
# https://github.com/lllyasviel/ControlNet

# %%
#!python gradio_canny2image.py

# %%
from PIL import Image

image = Image.open("controlnet-result.png").resize((1014,512))
image
# Out:
# <PIL.Image.Image image mode=RGBA size=1014x512>
